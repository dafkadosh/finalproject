# %%
import os
from tifffile import imread, imwrite

def clear_directory(directory):
    """Delete all files in the specified directory."""
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            os.rmdir(file_path)

def split_tiff(tiff_path, output_dir, is_label=False):
    # Read the TIFF file
    tiff_data = imread(tiff_path)

    # Check if the TIFF file contains multiple slices
    if len(tiff_data.shape) != 3:
        print("The TIFF file does not contain multiple slices.")
        return

    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)

    # Clear the output directory
    clear_directory(output_dir)

    # Initialize counter for slices
    counter = 0

    # Save the slices into the output directory
    for i, slice_data in enumerate(tiff_data):
        if is_label:
            slice_filename = f"image_{counter+1:03d}.tif"  # No channel suffix for labels
        else:
            slice_filename = f"image_{counter+1:03d}_0000.tif"  # Channel suffix for images
        
        slice_path = os.path.join(output_dir, slice_filename)
        print(f"Slice {i+1} saved as {slice_path}")
        counter += 1

        imwrite(slice_path, slice_data)

    print("Slicing complete.")

# Specify the path to your image and label TIFF files
image_tiff_path = r"/argusdata/users/undergrads/ItamarAndDafna/Final_Project_rawdata/10_30_HIGH_5_LOW 2CR/M1/Interpolated_GlyR_M1_stack_dafna.tif"
label_tiff_path = r"/argusdata/users/undergrads/ItamarAndDafna/Final_Project_rawdata/10_30_HIGH_5_LOW 2CR/M1/initial_mask_substack.tif"

# Specify the output directories for saving all slices
image_output_dir = r"/argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset031_1030GlyRM1_noSplit/imagesTs"
label_output_dir = r"/argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset031_1030GlyRM1_noSplit/labelsTs"

# Call the function to split the image TIFF file into individual slices (with channel suffix)
split_tiff(image_tiff_path, image_output_dir)

# Call the function to split the label TIFF file into individual slices (without channel suffix)
split_tiff(label_tiff_path, label_output_dir, is_label=True)
# Out:
# Slice 1 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_001_0000.tif
# Slice 2 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_002_0000.tif
# Slice 3 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_003_0000.tif
# Slice 4 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_004_0000.tif
# Slice 5 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_005_0000.tif
# Slice 6 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_006_0000.tif
# Slice 7 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_007_0000.tif
# Slice 8 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_008_0000.tif
# Slice 9 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_009_0000.tif
# Slice 10 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_010_0000.tif
# Slice 11 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_011_0000.tif
# Slice 12 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_012_0000.tif
# Slice 13 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_013_0000.tif
# Slice 14 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_014_0000.tif
# Slice 15 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_015_0000.tif
# Slice 16 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_016_0000.tif
# Slice 17 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_017_0000.tif
# Slice 18 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_018_0000.tif
# Slice 19 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_019_0000.tif
# Slice 20 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_020_0000.tif
# Slice 21 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_021_0000.tif
# Slice 22 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_022_0000.tif
# Slice 23 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_023_0000.tif
# Slice 24 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_024_0000.tif
# Slice 25 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_025_0000.tif
# Slice 26 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_026_0000.tif
# Slice 27 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_027_0000.tif
# Slice 28 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_028_0000.tif
# Slice 29 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_029_0000.tif
# Slice 30 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_030_0000.tif
# Slice 31 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_031_0000.tif
# Slice 32 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_032_0000.tif
# Slice 33 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_033_0000.tif
# Slice 34 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_034_0000.tif
# Slice 35 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_035_0000.tif
# Slice 36 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_036_0000.tif
# Slice 37 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_037_0000.tif
# Slice 38 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_038_0000.tif
# Slice 39 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_039_0000.tif
# Slice 40 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_040_0000.tif
# Slice 41 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_041_0000.tif
# Slice 42 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_042_0000.tif
# Slice 43 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_043_0000.tif
# Slice 44 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_044_0000.tif
# Slice 45 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_045_0000.tif
# Slice 46 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_046_0000.tif
# Slice 47 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_047_0000.tif
# Slice 48 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_048_0000.tif
# Slice 49 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_049_0000.tif
# Slice 50 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_050_0000.tif
# Slice 51 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_051_0000.tif
# Slice 52 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_052_0000.tif
# Slice 53 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_053_0000.tif
# Slice 54 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_054_0000.tif
# Slice 55 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_055_0000.tif
# Slice 56 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_056_0000.tif
# Slice 57 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_057_0000.tif
# Slice 58 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_058_0000.tif
# Slice 59 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_059_0000.tif
# Slice 60 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_060_0000.tif
# Slice 61 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_061_0000.tif
# Slice 62 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_062_0000.tif
# Slice 63 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_063_0000.tif
# Slice 64 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_064_0000.tif
# Slice 65 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_065_0000.tif
# Slice 66 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_066_0000.tif
# Slice 67 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_067_0000.tif
# Slice 68 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_068_0000.tif
# Slice 69 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_069_0000.tif
# Slice 70 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_070_0000.tif
# Slice 71 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_071_0000.tif
# Slice 72 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_072_0000.tif
# Slice 73 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_073_0000.tif
# Slice 74 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_074_0000.tif
# Slice 75 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_075_0000.tif
# Slice 76 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_076_0000.tif
# Slice 77 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_077_0000.tif
# Slice 78 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_078_0000.tif
# Slice 79 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_079_0000.tif
# Slice 80 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_080_0000.tif
# Slice 81 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_081_0000.tif
# Slice 82 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_082_0000.tif
# Slice 83 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_083_0000.tif
# Slice 84 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_084_0000.tif
# Slice 85 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_085_0000.tif
# Slice 86 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_086_0000.tif
# Slice 87 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_087_0000.tif
# Slice 88 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_088_0000.tif
# Slice 89 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_089_0000.tif
# Slice 90 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_090_0000.tif
# Slice 91 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_091_0000.tif
# Slice 92 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_092_0000.tif
# Slice 93 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_093_0000.tif
# Slice 94 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_094_0000.tif
# Slice 95 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_095_0000.tif
# Slice 96 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_096_0000.tif
# Slice 97 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_097_0000.tif
# Slice 98 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_098_0000.tif
# Slice 99 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_099_0000.tif
# Slice 100 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_100_0000.tif
# Slice 101 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_101_0000.tif
# Slice 102 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_102_0000.tif
# Slice 103 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_103_0000.tif
# Slice 104 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_104_0000.tif
# Slice 105 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_105_0000.tif
# Slice 106 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_106_0000.tif
# Slice 107 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_107_0000.tif
# Slice 108 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_108_0000.tif
# Slice 109 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_109_0000.tif
# Slice 110 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_110_0000.tif
# Slice 111 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_111_0000.tif
# Slice 112 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_112_0000.tif
# Slice 113 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_113_0000.tif
# Slice 114 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_114_0000.tif
# Slice 115 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_115_0000.tif
# Slice 116 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_116_0000.tif
# Slice 117 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_117_0000.tif
# Slice 118 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_118_0000.tif
# Slice 119 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_119_0000.tif
# Slice 120 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_120_0000.tif
# Slice 121 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_121_0000.tif
# Slice 122 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_122_0000.tif
# Slice 123 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/imagesTs/image_123_0000.tif
# Slicing complete.
# Slice 1 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_001.tif
# Slice 2 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_002.tif
# Slice 3 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_003.tif
# Slice 4 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_004.tif
# Slice 5 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_005.tif
# Slice 6 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_006.tif
# Slice 7 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_007.tif
# Slice 8 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_008.tif
# Slice 9 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_009.tif
# Slice 10 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_010.tif
# Slice 11 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_011.tif
# Slice 12 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_012.tif
# Slice 13 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_013.tif
# Slice 14 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_014.tif
# Slice 15 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_015.tif
# Slice 16 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_016.tif
# Slice 17 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_017.tif
# Slice 18 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_018.tif
# Slice 19 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_019.tif
# Slice 20 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_020.tif
# Slice 21 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_021.tif
# Slice 22 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_022.tif
# Slice 23 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_023.tif
# Slice 24 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_024.tif
# Slice 25 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_025.tif
# Slice 26 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_026.tif
# Slice 27 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_027.tif
# Slice 28 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_028.tif
# Slice 29 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_029.tif
# Slice 30 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_030.tif
# Slice 31 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_031.tif
# Slice 32 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_032.tif
# Slice 33 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_033.tif
# Slice 34 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_034.tif
# Slice 35 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_035.tif
# Slice 36 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_036.tif
# Slice 37 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_037.tif
# Slice 38 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_038.tif
# Slice 39 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_039.tif
# Slice 40 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_040.tif
# Slice 41 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_041.tif
# Slice 42 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_042.tif
# Slice 43 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_043.tif
# Slice 44 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_044.tif
# Slice 45 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_045.tif
# Slice 46 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_046.tif
# Slice 47 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_047.tif
# Slice 48 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_048.tif
# Slice 49 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_049.tif
# Slice 50 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_050.tif
# Slice 51 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_051.tif
# Slice 52 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_052.tif
# Slice 53 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_053.tif
# Slice 54 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_054.tif
# Slice 55 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_055.tif
# Slice 56 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_056.tif
# Slice 57 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_057.tif
# Slice 58 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_058.tif
# Slice 59 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_059.tif
# Slice 60 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_060.tif
# Slice 61 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_061.tif
# Slice 62 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_062.tif
# Slice 63 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_063.tif
# Slice 64 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_064.tif
# Slice 65 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_065.tif
# Slice 66 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_066.tif
# Slice 67 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_067.tif
# Slice 68 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_068.tif
# Slice 69 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_069.tif
# Slice 70 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_070.tif
# Slice 71 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_071.tif
# Slice 72 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_072.tif
# Slice 73 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_073.tif
# Slice 74 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_074.tif
# Slice 75 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_075.tif
# Slice 76 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_076.tif
# Slice 77 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_077.tif
# Slice 78 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_078.tif
# Slice 79 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_079.tif
# Slice 80 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_080.tif
# Slice 81 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_081.tif
# Slice 82 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_082.tif
# Slice 83 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_083.tif
# Slice 84 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_084.tif
# Slice 85 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_085.tif
# Slice 86 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_086.tif
# Slice 87 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_087.tif
# Slice 88 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_088.tif
# Slice 89 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_089.tif
# Slice 90 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_090.tif
# Slice 91 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_091.tif
# Slice 92 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_092.tif
# Slice 93 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_093.tif
# Slice 94 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_094.tif
# Slice 95 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_095.tif
# Slice 96 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_096.tif
# Slice 97 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_097.tif
# Slice 98 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_098.tif
# Slice 99 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_099.tif
# Slice 100 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_100.tif
# Slice 101 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_101.tif
# Slice 102 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_102.tif
# Slice 103 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_103.tif
# Slice 104 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_104.tif
# Slice 105 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_105.tif
# Slice 106 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_106.tif
# Slice 107 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_107.tif
# Slice 108 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_108.tif
# Slice 109 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_109.tif
# Slice 110 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_110.tif
# Slice 111 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_111.tif
# Slice 112 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_112.tif
# Slice 113 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_113.tif
# Slice 114 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_114.tif
# Slice 115 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_115.tif
# Slice 116 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_116.tif
# Slice 117 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_117.tif
# Slice 118 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_118.tif
# Slice 119 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_119.tif
# Slice 120 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_120.tif
# Slice 121 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_121.tif
# Slice 122 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_122.tif
# Slice 123 saved as /argusdata/users/undergrads/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset030_1030GlyRM1_noSplit/labelsTs/image_123.tif
# Slicing complete.
