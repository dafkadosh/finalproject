# %%
import shutil
import os

# Function to copy all files from one directory to another with renaming if needed
def copy_files_with_renaming(src_dir, dst_dir, file_counter_start):
    if os.path.exists(src_dir):
        os.makedirs(dst_dir, exist_ok=True)
        
        # Get the maximum file number in the destination directory
        dst_files = os.listdir(dst_dir)
        if dst_files:
            max_number = max(int(f.split('_')[-1].split('.')[0]) for f in dst_files)
        else:
            max_number = file_counter_start - 1 if file_counter_start is not None else 0  # Start from the initial counter - 1

        for file_name in os.listdir(src_dir):
            full_file_name = os.path.join(src_dir, file_name)
            if os.path.isfile(full_file_name):
                # Extract the base name and extension
                base, ext = os.path.splitext(file_name)
                
                # Extract number from the end of the file name
                parts = base.split('_')
                num = int(parts[-1])
                
                # Calculate new number based on the maximum number in the destination folder
                new_num = max_number + 1 + num - (file_counter_start if file_counter_start is not None else 0)
                
                # Construct new file name
                new_file_name = f"{'_'.join(parts[:-1])}_{new_num:04d}{ext}"
                
                # Copy file to destination
                shutil.copy2(full_file_name, os.path.join(dst_dir, new_file_name))
                print(f"Copied {full_file_name} to {os.path.join(dst_dir, new_file_name)}")
                
                # Update max_number
                max_number = max(max_number, new_num)

# Function to delete all files inside the folders in the new_base_path
def delete_files_in_directory(directory):
    if os.path.exists(directory):
        for root, dirs, files in os.walk(directory):
            for file in files:
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f"Deleted {file_path}")

# Function to process each dataset folder
def process_datasets(datasets_path, new_base_path):
    # First, delete all files in the destination folders
    delete_files_in_directory(os.path.join(new_base_path, 'imagesTr'))
    delete_files_in_directory(os.path.join(new_base_path, 'imagesTs'))
    delete_files_in_directory(os.path.join(new_base_path, 'labelsTr'))
    delete_files_in_directory(os.path.join(new_base_path, 'labelsTs'))

    # Initialize counters for each subdirectory
    file_counter_imagesTr = None
    file_counter_imagesTs = None
    file_counter_labelsTr = None
    file_counter_labelsTs = None

    for dataset_folder in os.listdir(datasets_path):
        dataset_path = os.path.join(datasets_path, dataset_folder)
        
        # Skip the destination folder
        if os.path.isdir(dataset_path) and os.path.abspath(dataset_path) != os.path.abspath(new_base_path):
            # Define source and destination directories
            imagesTr_src = os.path.join(dataset_path, 'imagesTr')
            imagesTr_dst = os.path.join(new_base_path, 'imagesTr')
            imagesTs_src = os.path.join(dataset_path, 'imagesTs')
            imagesTs_dst = os.path.join(new_base_path, 'imagesTs')
            labelsTr_src = os.path.join(dataset_path, 'labelsTr')
            labelsTr_dst = os.path.join(new_base_path, 'labelsTr')
            labelsTs_src = os.path.join(dataset_path, 'labelsTs')
            labelsTs_dst = os.path.join(new_base_path, 'labelsTs')

            # Copy files for each subdirectory with renaming
            file_counter_imagesTr = copy_files_with_renaming(imagesTr_src, imagesTr_dst, file_counter_imagesTr)
            file_counter_imagesTs = copy_files_with_renaming(imagesTs_src, imagesTs_dst, file_counter_imagesTs)
            file_counter_labelsTr = copy_files_with_renaming(labelsTr_src, labelsTr_dst, file_counter_labelsTr)
            file_counter_labelsTs = copy_files_with_renaming(labelsTs_src, labelsTs_dst, file_counter_labelsTs)

# Example usage
datasets_path = r"/alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/"   # Replace with your datasets base path
new_base_path = r"/alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/"  # Replace with your new base path

process_datasets(datasets_path, new_base_path)
# Out:
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_001_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_002_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_003_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_004_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_005_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_006_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_007_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_008_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_009_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_010_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_011_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_012_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_013_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_014_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_015_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_016_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_017_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_018_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_019_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_020_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_021_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_022_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_023_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_024_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_025_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_026_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_027_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_028_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_029_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_030_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_031_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_032_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_033_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_034_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_035_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_036_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_037_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_038_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_039_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_040_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_041_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_042_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_001_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_002_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_003_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_004_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_005_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_006_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_007_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_008_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_009_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_010_0000.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/037_ge_0037.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/038_ge_0075.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/039_ge_0114.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/040_ge_0154.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/041_ge_0195.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/042_ge_0237.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/001_ge_0238.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/002_ge_0240.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/003_ge_0243.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/004_ge_0247.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/005_ge_0252.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/006_ge_0258.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/007_ge_0265.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/008_ge_0273.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/009_ge_0282.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/010_ge_0292.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/011_ge_0303.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/012_ge_0315.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/013_ge_0328.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/014_ge_0342.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/015_ge_0357.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/016_ge_0373.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/017_ge_0390.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/018_ge_0408.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/019_ge_0427.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/020_ge_0447.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/021_ge_0468.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/022_ge_0490.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/023_ge_0513.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/024_ge_0537.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/025_ge_0562.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/026_ge_0588.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/027_ge_0615.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/028_ge_0643.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/029_ge_0672.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/030_ge_0702.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/031_ge_0733.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/032_ge_0765.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/033_ge_0798.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/034_ge_0832.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/035_ge_0867.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/036_ge_0903.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0001.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0003.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0006.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0010.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0015.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0021.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0028.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0036.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0045.tif
# Deleted /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0055.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_001_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_001_0001.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_002_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_002_0002.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_003_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_003_0003.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_004_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_004_0004.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_005_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_005_0005.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_006_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_006_0006.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_007_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_007_0007.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_008_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_008_0008.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_009_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_009_0009.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_010_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_010_0010.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_011_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_011_0011.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_012_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_012_0012.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_013_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_013_0013.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_014_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_014_0014.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_015_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_015_0015.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_016_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_016_0016.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_017_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_017_0017.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_018_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_018_0018.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_019_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_019_0019.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_020_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_020_0020.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_021_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_021_0021.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_022_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_022_0022.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_023_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_023_0023.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_024_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_024_0024.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_025_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_025_0025.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_026_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_026_0026.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_027_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_027_0027.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_028_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_028_0028.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_029_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_029_0029.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_030_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_030_0030.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_031_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_031_0031.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_032_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_032_0032.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_033_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_033_0033.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_034_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_034_0034.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_035_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_035_0035.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_036_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_036_0036.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_037_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_037_0037.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_038_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_038_0038.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_039_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_039_0039.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_040_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_040_0040.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_041_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_041_0041.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTr/image_042_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_042_0042.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_001_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_001_0001.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_002_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_002_0002.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_003_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_003_0003.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_004_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_004_0004.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_005_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_005_0005.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_006_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_006_0006.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_007_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_007_0007.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_008_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_008_0008.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_009_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_009_0009.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/imagesTs/image_010_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTs/image_010_0010.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/037_ge_037.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/037_ge_0038.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/038_ge_038.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/038_ge_0077.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/039_ge_039.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/039_ge_0117.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/040_ge_040.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/040_ge_0158.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/041_ge_041.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/041_ge_0200.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/042_ge_042.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/042_ge_0243.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/001_ge_001.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/001_ge_0245.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/002_ge_002.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/002_ge_0248.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/003_ge_003.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/003_ge_0252.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/004_ge_004.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/004_ge_0257.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/005_ge_005.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/005_ge_0263.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/006_ge_006.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/006_ge_0270.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/007_ge_007.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/007_ge_0278.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/008_ge_008.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/008_ge_0287.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/009_ge_009.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/009_ge_0297.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/010_ge_010.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/010_ge_0308.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/011_ge_011.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/011_ge_0320.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/012_ge_012.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/012_ge_0333.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/013_ge_013.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/013_ge_0347.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/014_ge_014.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/014_ge_0362.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/015_ge_015.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/015_ge_0378.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/016_ge_016.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/016_ge_0395.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/017_ge_017.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/017_ge_0413.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/018_ge_018.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/018_ge_0432.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/019_ge_019.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/019_ge_0452.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/020_ge_020.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/020_ge_0473.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/021_ge_021.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/021_ge_0495.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/022_ge_022.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/022_ge_0518.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/023_ge_023.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/023_ge_0542.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/024_ge_024.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/024_ge_0567.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/025_ge_025.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/025_ge_0593.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/026_ge_026.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/026_ge_0620.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/027_ge_027.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/027_ge_0648.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/028_ge_028.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/028_ge_0677.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/029_ge_029.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/029_ge_0707.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/030_ge_030.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/030_ge_0738.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/031_ge_031.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/031_ge_0770.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/032_ge_032.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/032_ge_0803.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/033_ge_033.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/033_ge_0837.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/034_ge_034.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/034_ge_0872.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/035_ge_035.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/035_ge_0908.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTr/036_ge_036.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/036_ge_0945.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_001.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0002.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_002.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0005.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_003.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0009.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_004.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0014.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_005.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0020.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_006.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0027.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_007.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0035.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_008.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0044.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_009.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0054.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset024_1530640M1/labelsTs/image_010.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0065.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_001_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_001_0043.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_002_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_002_0044.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_003_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_003_0045.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_004_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_004_0046.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_005_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_005_0047.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_006_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_006_0048.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_007_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_007_0049.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_008_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_008_0050.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_009_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_009_0051.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_010_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_010_0052.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_011_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_011_0053.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_012_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_012_0054.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_013_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_013_0055.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_014_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_014_0056.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_015_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_015_0057.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_016_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_016_0058.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_017_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_017_0059.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_018_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_018_0060.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_019_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_019_0061.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_020_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_020_0062.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_021_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_021_0063.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_022_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_022_0064.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_023_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_023_0065.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_024_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_024_0066.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_025_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_025_0067.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_026_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_026_0068.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_027_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_027_0069.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_028_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_028_0070.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_029_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_029_0071.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_030_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_030_0072.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_031_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_031_0073.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_032_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_032_0074.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_033_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_033_0075.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_034_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_034_0076.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_035_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_035_0077.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_036_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_036_0078.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_037_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_037_0079.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_038_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_038_0080.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_039_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_039_0081.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_040_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_040_0082.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_041_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_041_0083.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_042_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_042_0084.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_043_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_043_0085.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_044_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_044_0086.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_045_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_045_0087.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_046_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_046_0088.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_047_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_047_0089.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_048_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_048_0090.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_049_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_049_0091.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_050_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_050_0092.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_051_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_051_0093.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_052_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_052_0094.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_053_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_053_0095.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_054_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_054_0096.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_055_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_055_0097.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_056_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_056_0098.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_057_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_057_0099.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_058_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_058_0100.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_059_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_059_0101.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_060_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_060_0102.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_061_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_061_0103.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_062_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_062_0104.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_063_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_063_0105.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_064_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_064_0106.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_065_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_065_0107.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_066_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_066_0108.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_067_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_067_0109.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_068_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_068_0110.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_069_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_069_0111.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_070_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_070_0112.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_071_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_071_0113.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_072_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_072_0114.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_073_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_073_0115.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_074_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_074_0116.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_075_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_075_0117.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_076_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_076_0118.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_077_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_077_0119.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_078_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_078_0120.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset025_1530640M2/imagesTr/image_079_0000.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/imagesTr/image_079_0121.tif
# ...
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_124.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_14489.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_125.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_14615.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_126.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_14742.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_127.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_14870.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_128.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_14999.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_129.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_15129.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_130.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_15260.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_131.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_15392.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_132.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_15525.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_133.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_15659.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_134.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_15794.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_135.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_15930.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_136.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_16067.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_137.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_16205.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_138.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_16344.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_139.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_16484.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_140.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_16625.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_141.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_16767.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_142.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_16910.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_143.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_17054.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_144.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_17199.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_145.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_17345.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_146.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_17492.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_147.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_17640.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_148.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_17789.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_149.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_17939.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_150.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_18090.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_151.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_18242.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_152.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_18395.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_153.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_18549.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_154.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_18704.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_155.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_18860.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_156.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_19017.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_157.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_19175.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_158.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_19334.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_159.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_19494.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_160.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_19655.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_161.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_19817.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_162.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_19980.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_163.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_20144.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTr/image_164.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTr/image_20309.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_001.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0444.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_002.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0447.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_003.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0451.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_004.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0456.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_005.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0462.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_006.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0469.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_007.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0477.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_008.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0486.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_009.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0496.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_010.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0507.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_011.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0519.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_012.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0532.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_013.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0546.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_014.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0561.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_015.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0577.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_016.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0594.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_017.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0612.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_018.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0631.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_019.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0651.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_020.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0672.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_021.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0694.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_022.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0717.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_023.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0741.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_024.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0766.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_025.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0792.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_026.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0819.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_027.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0847.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_028.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0876.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_029.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0906.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_030.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0937.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_031.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_0969.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_032.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_1002.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_033.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_1036.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_034.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_1071.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_035.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_1107.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_036.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_1144.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_037.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_1182.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_038.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_1221.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_039.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_1261.tif
# Copied /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset026_1330GlyRM2/labelsTs/image_040.tif to /alsxdata/ItamarAndDafna/nnUNet/nnUNet_raw/Dataset099_all_0000all_images/labelsTs/image_1302.tif
